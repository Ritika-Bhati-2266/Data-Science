# %%
empty_set=set()
print(empty_set)
print(type(empty_set))
# Out:
# set()
# <class 'set'>

# %%
my_set={1,2,3,4,5}
print(my_set)
print(type(my_set))
# Out:
# {1, 2, 3, 4, 5}
# <class 'set'>

# %%
my_set=set([1,1,2,2,3,4,5,6])
print(my_set)
print(type(my_set))
# Out:
# {1, 2, 3, 4, 5, 6}
# <class 'set'>

# %%
my_set={1,2,3,4,5,6}
my_set.add(8)
print(my_set)
# Out:
# {1, 2, 3, 4, 5, 6, 8}

# %%
my_set={1,2,3,4,5,6}
my_set.remove(11)
my_set.remove(6)
print(my_set)
# Out:
# {1, 2, 3, 4, 5}

# %%
my_set={1,2,3,4,5,6}
my_set.discard(6)
print(my_set)
# Out:
# {1, 2, 3, 4, 5}

# %%
my_set={1,2,3,4,5,6}
my_set.discard(85)
print(my_set)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
my_set={1,2,3,4,5,6}
removed_element=my_set.pop()
print(removed_element)
print(my_set)
# Out:
# 1
# {2, 3, 4, 5, 6}

# %%
my_set={1,2,3,4,5,6}
my_set.clear()
print(my_set)
# Out:
# set()

# %%
my_set={1,2,3,4,5,6}
print(3 in my_set)
print(10 in my_set)
# Out:
# True
# False

# %%
set1={1,2,3,4,5,6}
set2={4,5,6,7,8,9}
print(set1.union(set2))
print(set1.intersection(set2))
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}
# {4, 5, 6}

# %%
set1={1,2,3,4,5,6}
set2={4,5,6,7,8,9}
union_set=set1.union(set2)
print(union_set)

intersection_set=set1.intersection(set2)
print(intersection_set)

set1.intersection_update(set2)
print(set1)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}
# {4, 5, 6}
# {4, 5, 6}

# %%
set1={1,2,3,4,5,6}
set2={4,5,6,7,8,9}
print(set1.difference(set2))
print(set1)
# Out:
# {1, 2, 3}
# {1, 2, 3, 4, 5, 6}

# %%
set1={1,2,3,4,5,6}
set2={4,5,6,7,8,9}
print(set2.difference(set1))
print(set2)
# Out:
# {8, 9, 7}
# {4, 5, 6, 7, 8, 9}

# %%
set1={1,2,3,4,5,6}
set2={4,5,6,7,8,9}
# symmetric difference= remove coomon element 
print(set1.symmetric_difference(set2))
# Out:
# {1, 2, 3, 7, 8, 9}

# %%
set1={1,2,3}
set2={3,4,5}
print(set1.issubset(set2))
print(set1.issuperset(set2))
# Out:
# False
# False

# %%
lst=[1,2,2,3,4,4,5]
my_set=set(lst)
print(my_set)
# Out:
# {1, 2, 3, 4, 5}

# %%
lst=[1,2,2,3,4,4,5]
set(lst)
# Out:
# {1, 2, 3, 4, 5}

# %%
text="In this tutorial we are discussing about sets"
words=text.split()
unique_words=set(words)
print(unique_words)
# Out:
# {'this', 'tutorial', 'discussing', 'about', 'sets', 'are', 'we', 'In'}
