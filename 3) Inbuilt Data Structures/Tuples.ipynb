# %%
empty_tuple=()
print(empty_tuple)
print(type(empty_tuple))
# Out:
# ()
# <class 'tuple'>

# %%
lst=list()
print(lst)
print(type(lst))
# Out:
# []
# <class 'list'>

# %%
tpl=tuple()
print(tpl)
print(type(tpl))
# Out:
# ()
# <class 'tuple'>

# %%
numbers=tuple([1,2,3,4,5,6])
print(numbers)
print(type(numbers))
# Out:
# (1, 2, 3, 4, 5, 6)
# <class 'tuple'>

# %%
numbers=list((1,2,3,4,5,6))
print(numbers)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
mixed_tuple=(1,"Hello",3.14,True)
print(mixed_tuple)
# Out:
# (1, 'Hello', 3.14, True)

# %%
number=(1,2,3,4,5,6)
print(number[0])
print(number[-1])
print(numbers[1:])
print(number[::-1])
# Out:
# 1
# 6
# [2, 3, 4, 5, 6]
# (6, 5, 4, 3, 2, 1)

# %%
number=(1,2,3,4,5,6)
mixed_tuple=(1,"Hello",3.14,True)
concatenate=number+mixed_tuple
print(concatenate)
# Out:
# (1, 2, 3, 4, 5, 6, 1, 'Hello', 3.14, True)

# %%
mixed_tuple=(1,"Hello",3.14,True)
print(mixed_tuple*2)
# Out:
# (1, 'Hello', 3.14, True, 1, 'Hello', 3.14, True)

# %%
number=(1,2,3,4,5,6)
print(number*4)
# Out:
# (1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6, 1, 2, 3, 4, 5, 6)
