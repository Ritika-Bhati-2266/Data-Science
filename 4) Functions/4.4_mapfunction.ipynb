# %%
def square(x):
    return x*x
square(2)
# Out:
# 4

# %%
numbers=[1,2,3,4,5,6,7,8]
map(square,numbers)

# %%
numbers=[1,2,3,4,5,6,7,8]
list(map(square,numbers))
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64]

# %%
numbers=[1,2,3,4,5,6,7,8]
list(map(lambda x:x**2,numbers))
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64]

# %%
numbers1=[1,2,3]
numbers2=[4,5,6]
list(map(add,numbers1,numbers2))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 3
#       1 numbers1=[1,2,3]
#       2 numbers2=[4,5,6]
# ----> 3 list(map(add,numbers1,numbers2))
#
# NameError: name 'add' is not defined

# %%
numbers1=[1,2,3]
numbers2=[4,5,6]
list(map(lambda x,y:x+y,numbers1,numbers2))
# Out:
# [5, 7, 9]

# %%
str_numbers=['1','2','3','4','5']
int_numbers=list(map(int,str_numbers))
print(int_numbers)
# Out:
# [1, 2, 3, 4, 5]

# %%
words=['apple','banana','cherry']
upper_words=list(map(str.upper,words))
print(upper_words)
# Out:
# ['APPLE', 'BANANA', 'CHERRY']

# %%
def get_name(person):
    return person['name']
people=[
    {'name':"Krish",'age':32},
    {'name':"Jack",'age':44}
]
list(map(get_name,people))
# Out:
# ['Krish', 'Jack']
