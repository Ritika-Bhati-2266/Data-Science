# %%
num=24
if num%2==0:
    print("Even number")
else:
    print("Odd number")
# Out:
# Even number

# %%
def even_odd(num):
    if num%2==0:
        print("Even number")
    else:
        print("Odd number")
even_odd(41)
# Out:
# Odd number

# %%
def add(a,b):
    sum=a+b
    return sum
add(4,6)
# Out:
# 10

# %%
def add(a,b):
    return a+b
result=add(4,6)
print(result)
# Out:
# 10

# %%
def greet(name):
    print(f"Hello {name} Welcome to this course")
greet("Krish")
# Out:
# Hello Krish Welcome to this course

# %%
# def greet(name):
#     print(f"Hello {name} Welcome to this course")
# greet()

# %%
## Default parameter
def greet(name="Guest"):
    print(f"Hello {name} Welcome to this course")
greet()
# Out:
# Hello Guest Welcome to this course

# %%
def greet(name="Guest"):
    print(f"Hello {name} Welcome to this course")
greet("Krish")
# Out:
# Hello Krish Welcome to this course

# %%
def print_numbers(*krish):
    for number in krish:
        print(number)
print_numbers(1,4,7,8,9,4,6,8,"Hello")
# Out:
# 1
# 4
# 7
# 8
# 9
# 4
# 6
# 8
# Hello

# %%
def print_numbers(*args):
    for num in args:
        print(num)
print_numbers(1,3,4,6,8)
# Out:
# 1
# 3
# 4
# 6
# 8

# %%
def print_details(**kwargs):
    for key,value in kwargs.items():
        print(f"{key}:{value}")
print_details(name = "Krish", age = 32, country = "India")
# Out:
# name:Krish
# age:32
# country:India

# %%
def print_details(*args,**kwargs):
    for num in args:
        print(f" Positional argument: {num}")
    for key, value in kwargs.items():
        print(f"{key}:{value}")
print_details(1,3,2,4,6,7,"krish",name="Krish", age=32)
# print_details(1,3,2,4,6,7,"krish",name="Krish", age=32,8,9)
# Out:
#  Positional argument: 1
#  Positional argument: 3
#  Positional argument: 2
#  Positional argument: 4
#  Positional argument: 6
#  Positional argument: 7
#  Positional argument: krish
# name:Krish
# age:32

# %%
def multiply(a,b):
    return a*b
multiply(2,6)
# Out:
# 12

# %%
def multiply(a,b):
    return a*b,a
multiply(2,6)
# Out:
# (12, 2)
