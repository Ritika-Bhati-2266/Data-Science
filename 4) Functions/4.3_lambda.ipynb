# %%
# Syntax
lambda arguments :expression
# Out:
# <function __main__.<lambda>(arguments)>

# %%
def add(a,b):
    return a+b
add(2,6)
# Out:
# 8

# %%
add = lambda a,b :a+b
print(add(2,6))
# Out:
# 8
