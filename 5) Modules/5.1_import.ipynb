# %%
import math 
print(math.sqrt(2))
# Out:
# 1.4142135623730951

# %%
import math 
print(math.sqrt(16))
# Out:
# 4.0

# %%
from math import sqrt,pi
print(math.sqrt(4))
print(math.pi)
print(pi)
# Out:
# 2.0
# 3.141592653589793
# 3.141592653589793

# %%
import numpy as np
print(np.array([1,2,3,4,5]))
# Out:
# [1 2 3 4 5]

# %%
from math import *
print(math.sqrt(4))
print(pi)
# Out:
# 2.0
# 3.141592653589793

# %%
from package.maths import addition
print(addition(2,5))
# Out:
# 7

# %%
from package import maths
maths.addition(2,4)
# Out:
# 6

# %%
from package import maths
maths.subtraction(2,1)
# Out:
# 1
